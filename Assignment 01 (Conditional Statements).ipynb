# %% [markdown]
# 1) A company decided to give bonus of 5% to employee if his/her year of service is more than 5 years.
# Ask user for their salary and year of service and print the net bonus amount.

# %%
#Type your code here
user_service=int((input("How many years of your service in our company")))
user_salary=int((input("what is your salary")))
bonus=user_salary*5/100
if user_service>=5:
    print("you get 5 percentage bonus of your salary")
    if bonus==user_salary*5/100:
        print(f" you  get {bonus}bonus")
else:
    print("your service is below 5 years , you do not get any bonus")
# Out:
# you get 5 percentage bonus of your salary
#  you  get 50000.0bonus

# %% [markdown]
# 2) Write a program to check whether a person is eligible for voting or not. (accept age from user) if age is greater than 17 eligible otherwise not eligible

# %%
#Type your code here
user_age=int((input("what is your age")))
if user_age>17:
    print(" yes you are eligible for vote")
else :
    print("no you are not eligible for vote ")
# Out:
#  yes you are eligible for vote

# %% [markdown]
# 3) Write a program to check whether a number entered by user is even or odd.

# %%
#Type your code here
user_number=int(input("whatis your number"))
if  user_number %2:
    print ("user number is odd")
else:
    print("user number is even")
# Out:
# user number is odd

# %% [markdown]
# 4) Write a program to check whether a number is divisible by 7 or not.
# Show Answer

# %%
#Type your code here
num=int(input("enter a number"))
if num %7== 0:
    print("it is divisible by 7  ")
else:
    print("it is not  divisible by 7 ")
# Out:
# it is not  divisible by 7

# %% [markdown]
# 5) Write a program to display
# "Hello" if a number entered by user is a multiple of five , otherwise print "Bye".

# %%
#Type your code here
number=int((input("enter any number ")))
if number %5==0:
    print("hello")
else:
    print("bye")
# Out:
# hello

# %% [markdown]
# 6. Take values of length and breadth of a rectangle from user and print if it is square or rectangle.

# %%
#Type your code here 
lenght=int((input("what is your lenght")))
breadth=int((input("what is your breadth")))
if lenght==breadth:
    print("it is a square ")
else:
    print ("it is a rectangle")
# Out:
# it is a rectangle

# %% [markdown]
# 7. Take two int values from user and print greatest among them.

# %%
# Type your code here
num1=int((input("put a number")))
num2=int((input("again, put a number")))
if num1>num2:
    print("number 1 is grater than number 2")
else:
        print("number 2 is grater than number 1")
# Out:
# number 2 is grater than number 1

# %% [markdown]
# 8. A school has following rules for grading system:
#
# a. Below 25 - F
#
# b. 25 to 45 - E
#
# c. 45 to 50 - D
#
# d. 50 to 60 - C
#
# e. 60 to 80 - B
#
# f. Above 80 - A
#
# Ask user to enter marks and print the corresponding grade.

# %%
#Type your code here
mark=float(input ("enter your number"))
if mark >=80:
    print ("your grade is A")
elif    mark>=60:
    print("your grade is B")
elif    mark>=50:
    print("your grade is C")
elif  mark >=45:       
    print("your grade is D")
elif   mark>=25:
    print("your grade is E")
else:
    print("your grade is F")
# Out:
# your grade is F

# %% [markdown]
# 9. Ask user to enter age, gender ( M or F ), marital status ( Y or N ) and then using following rules print their place of service.
#
# if employee is female, then she will work only in urban areas.
#
# if employee is a male and age is in between 20 to 40 then he may work in anywhere
#
# if employee is male and age is in between 40 t0 60 then he will work in urban areas only.
#
# And any other input of age should print "ERROR"

# %%
#Type your code here
age=int((input("enter your age")))
gender=(input("what is your gender"))
marital=(input("you are married yes or no"))
if gender=="female":
    print("you will work only in urban areas")
elif gender=="male" and age > 20 and age < 40:
    print ("you may work anywhere")
elif gender=="male" and age > 40 and age < 60:
    print("you will work in urban areas")
else:
    print("ERROR")
# Out:
# ERROR
